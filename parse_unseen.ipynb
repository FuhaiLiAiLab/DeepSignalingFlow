# %% [markdown]
# # 1. NCI ALMANAC

# %% [markdown]
# ## 1.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-nci'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#             Drug A      Drug B Cell Line Name      Score
# 0        Dasatinib   Docetaxel         HCT-15  -4.777778
# 1     Streptozocin   Tretinoin         HOP-62 -12.000000
# 2      Thalidomide  Paclitaxel      NCI-H322M   1.888889
# 3         Mitotane   Sirolimus          SN12C  -7.666667
# 4        Sirolimus  Cladribine      NCI-H322M -18.555556
# ...            ...         ...            ...        ...
# 3937    Vorinostat   Nilotinib         DU-145  -4.555556
# 3938    Paclitaxel   Nilotinib         SF-268 -20.111111
# 3939      Mitotane   Nilotinib       CCRF-CEM  -8.444444
# 3940    Everolimus  Romidepsin         SW-620   0.222222
# 3941   Fulvestrant   Dasatinib         SNB-75   6.222222
#
# [3942 rows x 4 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['Celecoxib', 'Paclitaxel', 'Gefitinib', 'Cladribine', 'Sirolimus', 'Romidepsin', 'Tretinoin', 'Thalidomide', 'Vorinostat', 'Dasatinib', 'Docetaxel', 'Streptozocin', 'Nilotinib', 'Everolimus', 'Fulvestrant', 'Lenalidomide', 'Megestrol acetate', 'Mitotane']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 14 4

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#             Drug A      Drug B Cell Line Name      Score
# 0        Dasatinib   Docetaxel         HCT-15  -4.777778
# 1     Streptozocin   Tretinoin         HOP-62 -12.000000
# 2      Thalidomide  Paclitaxel      NCI-H322M   1.888889
# 3         Mitotane   Sirolimus          SN12C  -7.666667
# 4        Sirolimus  Cladribine      NCI-H322M -18.555556
# ...            ...         ...            ...        ...
# 3882    Vorinostat   Nilotinib         DU-145  -4.555556
# 3883    Paclitaxel   Nilotinib         SF-268 -20.111111
# 3884      Mitotane   Nilotinib       CCRF-CEM  -8.444444
# 3885    Everolimus  Romidepsin         SW-620   0.222222
# 3886   Fulvestrant   Dasatinib         SNB-75   6.222222
#
# [3887 rows x 4 columns]
#                Drug A        Drug B   Cell Line Name      Score
# 0   Megestrol acetate  Lenalidomide          NCI-H23  -6.888889
# 1   Megestrol acetate  Lenalidomide  MDA-MB-231/ATCC -17.444444
# 2   Megestrol acetate  Lenalidomide           HOP-92 -17.333333
# ...

# %% [markdown]
# ## 1.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 55
# ['SW-620', 'OVCAR-3', 'A549/ATCC', 'NCI-H226', 'NCI-H322M', 'UO-31', 'OVCAR-4', 'NCI-H460', 'TK-10', 'K-562', 'HCC-2998', 'OVCAR-5', 'LOX IMVI', 'CCRF-CEM', 'T-47D', 'U251', 'KM12', 'SN12C', 'SNB-75', 'M14', 'HT29', 'BT-549', 'RPMI-8226', 'MDA-MB-231/ATCC', 'SF-295', 'HS 578T', 'MOLT-4', 'PC-3', 'DU-145', 'SK-MEL-2', 'HOP-92', 'SF-539', 'HOP-62', 'ACHN', 'CAKI-1', 'OVCAR-8', 'SK-MEL-5', 'SF-268', 'SK-MEL-28', 'IGROV1', 'HCT-116', 'HCT-15', 'NCI-H522', 'SK-OV-3', 'MDA-MB-468', 'EKVX', '786-0', 'COLO 205', 'A498', 'UACC-62', 'MCF7', 'RXF 393', 'SR', 'UACC-257', 'NCI-H23']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 44 11

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#             Drug A      Drug B Cell Line Name      Score
# 0        Dasatinib   Docetaxel         HCT-15  -4.777778
# 1     Streptozocin   Tretinoin         HOP-62 -12.000000
# 2      Thalidomide  Paclitaxel      NCI-H322M   1.888889
# 3         Mitotane   Sirolimus          SN12C  -7.666667
# 4        Sirolimus  Cladribine      NCI-H322M -18.555556
# ...            ...         ...            ...        ...
# 3206    Vorinostat   Nilotinib         DU-145  -4.555556
# 3207    Paclitaxel   Nilotinib         SF-268 -20.111111
# 3208      Mitotane   Nilotinib       CCRF-CEM  -8.444444
# 3209    Everolimus  Romidepsin         SW-620   0.222222
# 3210   Fulvestrant   Dasatinib         SNB-75   6.222222
#
# [3211 rows x 4 columns]
#            Drug A        Drug B Cell Line Name      Score
# 0    Streptozocin    Paclitaxel           A498  -7.777778
# 1     Thalidomide    Paclitaxel           MCF7  -1.333333
# 2       Dasatinib     Celecoxib       UACC-257  -4.111111
# ...

# %% [markdown]
# # 2. ONEIL

# %% [markdown]
# ## 2.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-oneil'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#              Drug A        Drug B Cell Line Name      Score
# 0         Lapatinib     Dasatinib         HCT116 -13.812974
# 1         metformin     Lapatinib       MDAMB436 -14.631171
# 2     dexamethasone     Sunitinib         UACC62 -15.020938
# 3         Sunitinib  geldanamycin       NCI-H460   5.618969
# 4       vinblastine    Vorinostat       MDAMB436   0.146188
# ...             ...           ...            ...        ...
# 1465     Vorinostat  geldanamycin          CAOV3  -3.345314
# 1466      Dasatinib     Sorafenib          T-47D   5.893700
# 1467      Dasatinib     Sorafenib       NCI-H460   2.745770
# 1468     Vorinostat     Sunitinib           LOVO   2.533629
# 1469      Sunitinib     Dasatinib          T-47D   1.088079
#
# [1470 rows x 4 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['paclitaxel', 'Erlotinib', 'Vorinostat', 'vinblastine', 'dexamethasone', 'Sunitinib', 'Lapatinib', 'metformin', 'Dasatinib', 'Sorafenib', 'geldanamycin']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 8 3

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#              Drug A        Drug B Cell Line Name      Score
# 0         Lapatinib     Dasatinib         HCT116 -13.812974
# 1         metformin     Lapatinib       MDAMB436 -14.631171
# 2     dexamethasone     Sunitinib         UACC62 -15.020938
# 3         Sunitinib  geldanamycin       NCI-H460   5.618969
# 4       vinblastine    Vorinostat       MDAMB436   0.146188
# ...             ...           ...            ...        ...
# 1375    vinblastine  geldanamycin          OCUBM -16.848371
# 1376      Sunitinib     Lapatinib        SK-OV-3  16.185003
# 1377     Vorinostat  geldanamycin          CAOV3  -3.345314
# 1378     Vorinostat     Sunitinib           LOVO   2.533629
# 1379      Sunitinib     Dasatinib          T-47D   1.088079
#
# [1380 rows x 4 columns]
#           Drug A        Drug B Cell Line Name      Score
# 0      Dasatinib  geldanamycin          CAOV3  -5.399138
# 1      Dasatinib     Sorafenib        UWB1289   6.016967
# ...

# %% [markdown]
# ## 2.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 30
# ['SK-OV-3', 'RKO', 'HT29', 'UACC62', 'A2058', 'SW837', 'OV90', 'PA1', 'LOVO', 'RPMI7951', 'MDAMB436', 'NCIH1650', 'CAOV3', 'NCI-H460', 'HCT116', 'OVCAR3', 'SKMEL30', 'A375', 'NCIH23', 'NCIH520', 'A427', 'A2780', 'NCIH2122', 'HT144', 'T-47D', 'SW-620', 'OCUBM', 'SKMES1', 'VCAP', 'UWB1289']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 24 6

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#              Drug A        Drug B Cell Line Name      Score
# 0         Lapatinib     Dasatinib         HCT116 -13.812974
# 1         metformin     Lapatinib       MDAMB436 -14.631171
# 2     dexamethasone     Sunitinib         UACC62 -15.020938
# 3         Sunitinib  geldanamycin       NCI-H460   5.618969
# 4       vinblastine    Vorinostat       MDAMB436   0.146188
# ...             ...           ...            ...        ...
# 1171     Vorinostat     Dasatinib          CAOV3   5.588465
# 1172      Sunitinib     Lapatinib        SK-OV-3  16.185003
# 1173     Vorinostat  geldanamycin          CAOV3  -3.345314
# 1174      Dasatinib     Sorafenib       NCI-H460   2.745770
# 1175     Vorinostat     Sunitinib           LOVO   2.533629
#
# [1176 rows x 4 columns]
#           Drug A        Drug B Cell Line Name      Score
# 0      Dasatinib     Sorafenib        UWB1289   6.016967
# 1     Vorinostat  geldanamycin          OCUBM  -6.509065
# ...

# %% [markdown]
# # 3. DrugComb-fi

# %% [markdown]
# ## 3.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-drugcomb-fi'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#            Drug A       Drug B Cell Line Name Study Name      Score
# 0      paclitaxel    Sunitinib           ACHN    ALMANAC   5.671410
# 1      raloxifene   Vismodegib           HT29    ALMANAC  -4.762552
# 2        Axitinib   Vandetanib       UACC-257    ALMANAC   3.663130
# 3      Vismodegib     Axitinib       NCI-H522    ALMANAC   0.575967
# 4       Nilotinib  Enzastaurin       SK-MEL-5   FRIEDMAN -12.013209
# ...           ...          ...            ...        ...        ...
# 27776  raloxifene   Crizotinib        RXF 393    ALMANAC  -3.965202
# 27777  Crizotinib    Nilotinib        RXF 393    ALMANAC  -5.362582
# 27778  Crizotinib  Abiraterone            M14    ALMANAC   1.643903
# 27779   Sorafenib   Bexarotene       SK-MEL-5   FRIEDMAN   7.719935
# 27780  paclitaxel    Sunitinib       COLO 205    ALMANAC  -5.629454
#
# [27781 rows x 5 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['Sonidegib', 'Tolvaptan', 'norepinephrine', 'famotidine', 'oxybutynin', 'Vatalanib', 'Ambrisentan', 'Talmapimod', 'gabexate', 'Tivantinib', 'Tamibarotene', 'pentagastrin', 'piroxicam', 'Foretinib', 'theobromine', 'lovastatin', 'amoxapine', 'Olmesartan', 'Palbociclib', 'etodolac', 'loratadine', 'Tanespimycin', 'Glycyrrhizic acid', 'hydrochlorothiazide', 'Canertinib', 'zolmitriptan', 'Telmisartan', 'Dronedarone', 'Rimonabant', 'Gefitinib', 'flunarizine', 'dexamethasone', 'Cladribine', 'tetrahydropalmatine', 'felbamate', 'leflunomide', 'gossypol', 'Nepafenac', 'tenoxicam', 'Melatonin', 'tazarotene', 'Enzastaurin', 'Abiraterone', 'Roflumilast', 'progesterone', 'carvedilol', 'VERAPAMIL', 'dobutamine', 'MOXONIDINE', 'Dapoxetine', 'naringenin', 'lamotrigine', 'clonidine', 'phenoxybenzamine', 'ketoprofen', 'Cediranib', 'Fulvestrant', 'chloroquine', 'Amuvatinib', 'Pazopanib', 'TG100-115', 'Roxadustat', 'Romidepsin', 'aniracetam', 'Midostaurin', 'Tesmilifene', 'Binimetinib', 'histamine', 'gli
# ...

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 221 56

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#            Drug A       Drug B Cell Line Name Study Name      Score
# 0      paclitaxel    Sunitinib           ACHN    ALMANAC   5.671410
# 1      raloxifene   Vismodegib           HT29    ALMANAC  -4.762552
# 2        Axitinib   Vandetanib       UACC-257    ALMANAC   3.663130
# 3      Vismodegib     Axitinib       NCI-H522    ALMANAC   0.575967
# 4       Nilotinib  Enzastaurin       SK-MEL-5   FRIEDMAN -12.013209
# ...           ...          ...            ...        ...        ...
# 27208  raloxifene   Crizotinib        RXF 393    ALMANAC  -3.965202
# 27209  Crizotinib    Nilotinib        RXF 393    ALMANAC  -5.362582
# 27210  Crizotinib  Abiraterone            M14    ALMANAC   1.643903
# 27211   Sorafenib   Bexarotene       SK-MEL-5   FRIEDMAN   7.719935
# 27212  paclitaxel    Sunitinib       COLO 205    ALMANAC  -5.629454
#
# [27213 rows x 5 columns]
#            Drug A        Drug B Cell Line Name Study Name      Score
# ...

# %% [markdown]
# ## 3.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 105
# ...

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 84 21

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#             Drug A        Drug B Cell Line Name Study Name      Score
# 0       paclitaxel     Sunitinib           ACHN    ALMANAC   5.671410
# 1       raloxifene    Vismodegib           HT29    ALMANAC  -4.762552
# 2         Axitinib    Vandetanib       UACC-257    ALMANAC   3.663130
# 3      Ruxolitinib    Vandetanib          UO-31    ALMANAC   1.893364
# 4      Enzastaurin  Lestaurtinib        SKMEL30   FRIEDMAN  15.981750
# ...            ...           ...            ...        ...        ...
# 21602   Vismodegib      mitotane        OVCAR-8    ALMANAC   1.012335
# 21603  Abiraterone    raloxifene         OVCAR3    ALMANAC  -1.104269
# 21604   raloxifene    Crizotinib        RXF 393    ALMANAC  -3.965202
# 21605   Crizotinib     Nilotinib        RXF 393    ALMANAC  -5.362582
# 21606   Crizotinib   Abiraterone            M14    ALMANAC   1.643903
#
# [21607 rows x 5 columns]
#             Drug A       Drug B Cell Line Name Study Name      Score
# ...

# %% [markdown]
# # 4. DrugCombDB

# %% [markdown]
# ## 4.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-DrugCombDB'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#              Drug A            Drug B Cell Line Name    Score
# 0       VEMURAFENIB          IMATINIB          HT-29 -17.9000
# 1         DASATINIB       FULVESTRANT       NCI-H460  -2.5500
# 2       VEMURAFENIB         LAPATINIB         Caki-1   5.0800
# 3      MIFEPRISTONE       RUXOLITINIB         L-1236 -28.8310
# 4          AXITINIB       FULVESTRANT     MDA-MB-231  -8.9100
# ...             ...               ...            ...      ...
# 21394     DASATINIB         SORAFENIB          A-375  11.3075
# 21395     TRETINOIN         DASATINIB        SK-OV-3   1.9000
# 21396     SUNITINIB  ARSENIC TRIOXIDE           ACHN  -3.0600
# 21397   RUXOLITINIB          IMATINIB        U-251MG  -1.5500
# 21398     NILOTINIB          MITOTANE          T-47D  -4.3900
#
# [21399 rows x 4 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['NIFLUMIC ACID', 'LENALIDOMIDE', 'ADENOSINE', 'PERINDOPRIL', 'VORAPAXAR', 'GLYCYRRHIZIC ACID', 'OLMESARTAN', 'MINOCYCLINE', 'ROSIGLITAZONE', 'ZIPRASIDONE', 'OLANZAPINE', 'REGORAFENIB', 'ERLOTINIB', 'STREPTOZOCIN', 'FLUPHENAZINE', 'ARIPIPRAZOLE', 'BISOPROLOL', 'QUIZARTINIB', 'METHYLDOPA', 'PROPAFENONE', 'BIMATOPROST', 'GABEXATE', 'LESTAURTINIB', 'CVT6883', 'CABOZANTINIB', 'PIBOSEROD', 'SPERMIDINE', 'ACEMETACIN', 'PENTAGASTRIN', 'TOFACITINIB', 'PHENFORMIN', 'ILOPERIDONE', 'DIPYRIDAMOLE', 'NAPROXEN', 'LENVATINIB', 'METHYLENE BLUE', 'ETOMIDATE', 'SULINDAC', 'CLOZAPINE', 'GELDANAMYCIN', 'ACETYLCYSTEINE', 'LEVONORGESTREL', 'SALBUTAMOL', '2METHOXYESTRADIOL', 'BARDOXOLONE METHYL', 'SURAMIN', 'NEPAFENAC', 'CERULENIN', 'QUERCETIN', 'VATALANIB', 'DROSPIRENONE', 'OXYBUTYNIN', 'AMBRISENTAN', 'ESTRIOL', 'LICOFELONE', 'HISTAMINE', 'ANAGRELIDE', 'MELATONIN', 'ESTRAMUSTINE', 'KETOROLAC', 'PRAMIPEXOLE', 'MECLIZINE', 'SERATRODAST', 'GENISTEIN', 'NOREPINEPHRINE', 'CAFFEINE', 'FLUVASTATIN', 'COPANLISIB'
# ...

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 305 77

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#              Drug A            Drug B Cell Line Name    Score
# 0       VEMURAFENIB          IMATINIB          HT-29 -17.9000
# 1         DASATINIB       FULVESTRANT       NCI-H460  -2.5500
# 2       VEMURAFENIB         LAPATINIB         Caki-1   5.0800
# 3      MIFEPRISTONE       RUXOLITINIB         L-1236 -28.8310
# 4          AXITINIB       FULVESTRANT     MDA-MB-231  -8.9100
# ...             ...               ...            ...      ...
# 20011     DASATINIB         SORAFENIB          A-375  11.3075
# 20012     TRETINOIN         DASATINIB        SK-OV-3   1.9000
# 20013     SUNITINIB  ARSENIC TRIOXIDE           ACHN  -3.0600
# 20014   RUXOLITINIB          IMATINIB        U-251MG  -1.5500
# 20015     NILOTINIB          MITOTANE          T-47D  -4.3900
#
# [20016 rows x 4 columns]
#            Drug A       Drug B Cell Line Name  Score
# 0      VANDETANIB  VEMURAFENIB       COLO 205 -15.01
# 1      VANDETANIB    SORAFENIB       CCRF-CEM -17.64
# ...

# %% [markdown]
# ## 4.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 85
# ['A-549', 'HT-29', 'SF295', 'COLO 205', 'A-375', 'Caki-1', 'SN12C', 'HDLM-2', 'NCI-H322M', 'CCRF-CEM', 'PA-1', 'SK-MEL-28', 'RPMI-7951', 'SNB-75', 'NCI-H522', 'SK-OV-3', 'UACC-257', 'TK-10', 'A2058', 'HOP-62', 'T-47D', 'PC-3', 'BT-549', 'SF539', 'HCT 116', 'A-427', 'NCI-H226', 'NCI-H1650', '786-O', 'L-1236', 'RD', 'SR', 'OVCAR-5', 'A2780', 'MMAc-SF', 'OCUB-M', 'Hs 578T', 'VCaP', 'HT-144', 'RKO', 'MZ-MEL-7', 'OVCAR-4', 'KM12', 'ACHN', 'L-428', 'MCF-7', 'SW837', 'OVCAR-8', 'LoVo', 'MDA-MB-231', 'M14', 'A-498', 'RPMI-8226', 'NCI-H520', 'UWB1.289', 'IGROV-1', 'HCC2998', 'HCT 15', 'Caov-3', 'TC-71', 'MDA-MB-436', 'Huh-7', 'SK-MES-1', 'SW620', 'NCI-H460', 'EKVX', 'OV-90', 'MDA-MB-468', 'WM115', 'RXF 393L', 'K-562', 'NCI-H2122', 'SK-MEL-5', 'UACC-62', 'UO-31', 'SK-MEL-30', 'U-251MG', 'SK-MEL-2', 'LOX-IMVI', 'HOP-92', 'DU145', 'NCI-H23', 'SF268', 'OVCAR-3', 'MOLT-4']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 68 17

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#                   Drug A            Drug B Cell Line Name    Score
# 0            VEMURAFENIB          IMATINIB          HT-29 -17.9000
# 1              DASATINIB       FULVESTRANT       NCI-H460  -2.5500
# 2            VEMURAFENIB         LAPATINIB         Caki-1   5.0800
# 3           MIFEPRISTONE       RUXOLITINIB         L-1236 -28.8310
# 4               AXITINIB       FULVESTRANT     MDA-MB-231  -8.9100
# ...                  ...               ...            ...      ...
# 16337  MEGESTROL ACETATE       VEMURAFENIB       UACC-257 -39.0800
# 16338          DASATINIB         SORAFENIB          A-375  11.3075
# 16339          TRETINOIN         DASATINIB        SK-OV-3   1.9000
# 16340          SUNITINIB  ARSENIC TRIOXIDE           ACHN  -3.0600
# 16341          NILOTINIB          MITOTANE          T-47D  -4.3900
#
# [16342 rows x 4 columns]
#                  Drug A        Drug B Cell Line Name    Score
# 0           VINBLASTINE     SORAFENIB        UACC-62   5.2650
# ...
