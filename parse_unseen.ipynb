# %% [markdown]
# # 1. NCI ALMANAC

# %% [markdown]
# ## 1.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-nci'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#             Drug A      Drug B Cell Line Name      Score
# 0        Dasatinib   Docetaxel         HCT-15  -4.777778
# 1     Streptozocin   Tretinoin         HOP-62 -12.000000
# 2      Thalidomide  Paclitaxel      NCI-H322M   1.888889
# 3         Mitotane   Sirolimus          SN12C  -7.666667
# 4        Sirolimus  Cladribine      NCI-H322M -18.555556
# ...            ...         ...            ...        ...
# 3937    Vorinostat   Nilotinib         DU-145  -4.555556
# 3938    Paclitaxel   Nilotinib         SF-268 -20.111111
# 3939      Mitotane   Nilotinib       CCRF-CEM  -8.444444
# 3940    Everolimus  Romidepsin         SW-620   0.222222
# 3941   Fulvestrant   Dasatinib         SNB-75   6.222222
#
# [3942 rows x 4 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['Cladribine', 'Celecoxib', 'Fulvestrant', 'Megestrol acetate', 'Dasatinib', 'Lenalidomide', 'Everolimus', 'Streptozocin', 'Nilotinib', 'Tretinoin', 'Paclitaxel', 'Vorinostat', 'Sirolimus', 'Thalidomide', 'Docetaxel', 'Gefitinib', 'Romidepsin', 'Mitotane']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 14 4

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#             Drug A      Drug B Cell Line Name      Score
# 0        Dasatinib   Docetaxel         HCT-15  -4.777778
# 1     Streptozocin   Tretinoin         HOP-62 -12.000000
# 2      Thalidomide  Paclitaxel      NCI-H322M   1.888889
# 3         Mitotane   Sirolimus          SN12C  -7.666667
# 4        Sirolimus  Cladribine      NCI-H322M -18.555556
# ...            ...         ...            ...        ...
# 3791    Vorinostat   Nilotinib         DU-145  -4.555556
# 3792    Paclitaxel   Nilotinib         SF-268 -20.111111
# 3793      Mitotane   Nilotinib       CCRF-CEM  -8.444444
# 3794    Everolimus  Romidepsin         SW-620   0.222222
# 3795   Fulvestrant   Dasatinib         SNB-75   6.222222
#
# [3796 rows x 4 columns]
#           Drug A      Drug B   Cell Line Name      Score
# 0    Fulvestrant  Cladribine           SF-539  -7.333333
# 1     Everolimus  Cladribine         NCI-H226   0.222222
# 2    Fulvestrant  Cladribine           BT-549  -3.111111
# 3     Everolimus  Cladribine        RPMI-8226  -8.666667
# 4    Fulvestrant  Cladribine           MOLT-4  -5.777778
# ..           ...         ...              ...        ...
# 141   Everolimus  Cladribine             HT29   0.777778
# 142  Fulvestrant  Everolimus           HOP-92  -3.777778
# 143  Fulvestrant  Everolimus       MDA-MB-468  28.444444
# 144   Everolimus  Cladribine  MDA-MB-231/ATCC  -2.666667
# 145   Everolimus  Cladribine             U251  -5.444444
#
# [146 rows x 4 columns]

# %% [markdown]
# ## 1.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 55
# ['SF-268', '786-0', 'SF-295', 'SK-MEL-5', 'EKVX', 'T-47D', 'SK-OV-3', 'NCI-H226', 'ACHN', 'UACC-62', 'LOX IMVI', 'SK-MEL-2', 'M14', 'NCI-H23', 'RPMI-8226', 'BT-549', 'U251', 'HCT-15', 'COLO 205', 'HOP-92', 'SNB-75', 'SW-620', 'NCI-H322M', 'RXF 393', 'MDA-MB-468', 'SR', 'HCT-116', 'CAKI-1', 'OVCAR-8', 'OVCAR-4', 'A498', 'MOLT-4', 'TK-10', 'DU-145', 'K-562', 'NCI-H460', 'NCI-H522', 'MCF7', 'KM12', 'SN12C', 'SF-539', 'OVCAR-5', 'HT29', 'UACC-257', 'UO-31', 'PC-3', 'MDA-MB-231/ATCC', 'IGROV1', 'HOP-62', 'A549/ATCC', 'CCRF-CEM', 'HCC-2998', 'HS 578T', 'OVCAR-3', 'SK-MEL-28']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 44 11

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#            Drug A      Drug B Cell Line Name      Score
# 0       Dasatinib   Docetaxel         HCT-15  -4.777778
# 1     Thalidomide  Paclitaxel      NCI-H322M   1.888889
# 2        Mitotane   Sirolimus          SN12C  -7.666667
# 3       Sirolimus  Cladribine      NCI-H322M -18.555556
# 4      Romidepsin  Paclitaxel       LOX IMVI  -2.333333
# ...           ...         ...            ...        ...
# 3075    Docetaxel   Celecoxib         SW-620  12.222222
# 3076   Vorinostat   Nilotinib         DU-145  -4.555556
# 3077   Paclitaxel   Nilotinib         SF-268 -20.111111
# 3078   Everolimus  Romidepsin         SW-620   0.222222
# 3079  Fulvestrant   Dasatinib         SNB-75   6.222222
#
# [3080 rows x 4 columns]
#            Drug A      Drug B Cell Line Name      Score
# 0    Streptozocin   Tretinoin         HOP-62 -12.000000
# 1      Everolimus  Romidepsin        HS 578T   1.111111
# 2        Mitotane  Cladribine        OVCAR-3  -3.222222
# 3    Streptozocin  Paclitaxel         HOP-62  -0.888889
# 4    Streptozocin  Cladribine       CCRF-CEM  -4.888889
# ..            ...         ...            ...        ...
# 857   Fulvestrant   Dasatinib         IGROV1   7.333333
# 858     Sirolimus    Mitotane       CCRF-CEM  -2.111111
# 859     Docetaxel  Paclitaxel      SK-MEL-28   0.333333
# 860    Paclitaxel   Tretinoin          UO-31   4.000000
# 861      Mitotane   Nilotinib       CCRF-CEM  -8.444444
#
# [862 rows x 4 columns]

# %% [markdown]
# # 2. ONEIL

# %% [markdown]
# ## 2.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-oneil'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#              Drug A        Drug B Cell Line Name      Score
# 0         Lapatinib     Dasatinib         HCT116 -13.812974
# 1         metformin     Lapatinib       MDAMB436 -14.631171
# 2     dexamethasone     Sunitinib         UACC62 -15.020938
# 3         Sunitinib  geldanamycin       NCI-H460   5.618969
# 4       vinblastine    Vorinostat       MDAMB436   0.146188
# ...             ...           ...            ...        ...
# 1465     Vorinostat  geldanamycin          CAOV3  -3.345314
# 1466      Dasatinib     Sorafenib          T-47D   5.893700
# 1467      Dasatinib     Sorafenib       NCI-H460   2.745770
# 1468     Vorinostat     Sunitinib           LOVO   2.533629
# 1469      Sunitinib     Dasatinib          T-47D   1.088079
#
# [1470 rows x 4 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['vinblastine', 'metformin', 'Vorinostat', 'Sorafenib', 'Erlotinib', 'Dasatinib', 'geldanamycin', 'dexamethasone', 'Lapatinib', 'paclitaxel', 'Sunitinib']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 8 3

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#              Drug A        Drug B Cell Line Name      Score
# 0         Lapatinib     Dasatinib         HCT116 -13.812974
# 1         metformin     Lapatinib       MDAMB436 -14.631171
# 2     dexamethasone     Sunitinib         UACC62 -15.020938
# 3         Sunitinib  geldanamycin       NCI-H460   5.618969
# 4       vinblastine    Vorinostat       MDAMB436   0.146188
# ...             ...           ...            ...        ...
# 1375     Vorinostat  geldanamycin          CAOV3  -3.345314
# 1376      Dasatinib     Sorafenib          T-47D   5.893700
# 1377      Dasatinib     Sorafenib       NCI-H460   2.745770
# 1378     Vorinostat     Sunitinib           LOVO   2.533629
# 1379      Sunitinib     Dasatinib          T-47D   1.088079
#
# [1380 rows x 4 columns]
#         Drug A     Drug B Cell Line Name      Score
# 0    Sunitinib  Lapatinib         SW-620 -14.238287
# 1   paclitaxel  Lapatinib            RKO  -2.306526
# 2   paclitaxel  Sunitinib       MDAMB436  -0.692048
# 3   paclitaxel  Sunitinib        SKMEL30  -0.264214
# 4    Sunitinib  Lapatinib         OVCAR3   9.135650
# ..         ...        ...            ...        ...
# 85  paclitaxel  Sunitinib          T-47D -24.395430
# 86  paclitaxel  Lapatinib            PA1   0.464604
# 87  paclitaxel  Sunitinib         UACC62   0.080443
# 88  paclitaxel  Sunitinib         OVCAR3 -16.967828
# 89   Sunitinib  Lapatinib        SK-OV-3  16.185003
#
# [90 rows x 4 columns]

# %% [markdown]
# ## 2.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 30
# ['T-47D', 'SK-OV-3', 'OCUBM', 'SW-620', 'HT144', 'A375', 'NCIH1650', 'RKO', 'UACC62', 'OV90', 'LOVO', 'HCT116', 'MDAMB436', 'A2058', 'VCAP', 'A427', 'NCIH520', 'SKMES1', 'CAOV3', 'SKMEL30', 'NCIH23', 'PA1', 'NCI-H460', 'OVCAR3', 'UWB1289', 'SW837', 'A2780', 'RPMI7951', 'HT29', 'NCIH2122']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 24 6

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#              Drug A        Drug B Cell Line Name      Score
# 0         Lapatinib     Dasatinib         HCT116 -13.812974
# 1         metformin     Lapatinib       MDAMB436 -14.631171
# 2     dexamethasone     Sunitinib         UACC62 -15.020938
# 3         Sunitinib  geldanamycin       NCI-H460   5.618969
# 4       vinblastine    Vorinostat       MDAMB436   0.146188
# ...             ...           ...            ...        ...
# 1171     Vorinostat  geldanamycin          CAOV3  -3.345314
# 1172      Dasatinib     Sorafenib          T-47D   5.893700
# 1173      Dasatinib     Sorafenib       NCI-H460   2.745770
# 1174     Vorinostat     Sunitinib           LOVO   2.533629
# 1175      Sunitinib     Dasatinib          T-47D   1.088079
#
# [1176 rows x 4 columns]
#             Drug A        Drug B Cell Line Name      Score
# 0        Lapatinib     Sorafenib       RPMI7951  -2.204580
# 1        Dasatinib     Sorafenib        UWB1289   6.016967
# 2       paclitaxel     Erlotinib        UWB1289   1.999340
# 3        Erlotinib     Dasatinib        UWB1289  12.558058
# 4       paclitaxel     Sorafenib          SW837  -5.800671
# ..             ...           ...            ...        ...
# 289      Erlotinib  geldanamycin       NCIH2122   3.084437
# 290  dexamethasone     Dasatinib           HT29 -13.563016
# 291    vinblastine     Sorafenib           HT29  -2.024027
# 292      metformin  geldanamycin          SW837 -23.893455
# 293     paclitaxel     Sorafenib       RPMI7951  -6.183577
#
# [294 rows x 4 columns]

# %% [markdown]
# # 3. DrugComb-fi

# %% [markdown]
# ## 3.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-drugcomb-fi'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#            Drug A       Drug B Cell Line Name Study Name      Score
# 0      paclitaxel    Sunitinib           ACHN    ALMANAC   5.671410
# 1      raloxifene   Vismodegib           HT29    ALMANAC  -4.762552
# 2        Axitinib   Vandetanib       UACC-257    ALMANAC   3.663130
# 3      Vismodegib     Axitinib       NCI-H522    ALMANAC   0.575967
# 4       Nilotinib  Enzastaurin       SK-MEL-5   FRIEDMAN -12.013209
# ...           ...          ...            ...        ...        ...
# 27776  raloxifene   Crizotinib        RXF 393    ALMANAC  -3.965202
# 27777  Crizotinib    Nilotinib        RXF 393    ALMANAC  -5.362582
# 27778  Crizotinib  Abiraterone            M14    ALMANAC   1.643903
# 27779   Sorafenib   Bexarotene       SK-MEL-5   FRIEDMAN   7.719935
# 27780  paclitaxel    Sunitinib       COLO 205    ALMANAC  -5.629454
#
# [27781 rows x 5 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['Bexarotene', 'CICLOPIROX', 'Dapoxetine', 'azelastine', 'Dasatinib', 'indomethacin', 'bufexamac', 'loperamide', 'sulpiride', 'Trametinib', 'xylometazoline', 'Conivaptan', 'Roflumilast', 'amlexanox', 'vinblastine', 'TG100-115', 'Navitoclax', 'amisulpride', 'sumatriptan', 'Venetoclax', 'tazarotene', 'VERAPAMIL', 'Crizotinib', 'Tanespimycin', 'dyphylline', 'Talmapimod', 'OSI-930', 'Piboserod', 'mifepristone', 'betaxolol', 'gossypol', 'Plerixafor', 'Synephrine', 'Lestaurtinib', 'Ambrisentan', 'Prucalopride', 'taurine', 'Sorafenib', 'ADAPALENE', 'dexamethasone', 'PH-797804', 'ketorolac', 'Enzastaurin', 'rosiglitazone', 'Erteberel', 'Olmesartan', 'rolipram', 'loratadine', 'anagrelide', 'tetrahydropalmatine', 'arecoline', 'Cinacalcet', 'alfuzosin', 'Flupirtine', 'epinephrine', 'Amuvatinib', 'spermidine', 'SNS-032', 'Melatonin', 'flunarizine', 'genistein', 'Ketanserin', 'Fulvestrant', 'Lumacaftor', 'ondansetron', 'TETRABENAZINE', 'Lonafarnib', 'Fasudil', 'Nafamostat', 'methyldopa', 'Dabrafenib', 'methyltestosterone', 'simvastatin', 'Dronedarone', 'risperidone', 'Rhein', 'PHENFORMIN', 'prazosin', 'Iloperidone', 'Palbociclib', 'acemetacin', 'aniracetam', 'Mocetinostat', 'Vandetanib', 'Aprepitant', 'XL765', 'maprotiline', 'Rimonabant', 'CVT-6883', 'Roxadustat', 'naringenin', 'clofibrate', 'Pazopanib', 'PERINDOPRIL', 'glipizide', 'amantadine', 'domperidone', 'Licofelone', 'zolmitriptan', 'lovastatin', 'Pizotifen', 'menadione', 'Erlotinib', 'celecoxib', 'lamotrigine', 'lansoprazole', 'Gefitinib', 'Aripiprazole', 'Belinostat', 'dobutamine', 'chloroquine', 'Telmisartan', 'fenoldopam', 'biperiden', 'ketotifen', 'nateglinide', 'thalidomide', 'NAPROXEN', 'niflumic acid', 'orphenadrine', 'meloxicam', 'rofecoxib', 'Nilotinib', 'Vemurafenib', 'clomipramine', 'Vismodegib', 'argatroban', 'Ivacaftor', 'rizatriptan', 'diphenhydramine', 'Salbutamol', 'metformin', 'Tandutinib', 'troglitazone', 'progesterone', 'FLUPHENAZINE', 'raloxifene', 'fenofibrate', 'Vorinostat', 'berberine', 'Axitinib', 'piroxicam', 'MK-0354', 'Lapatinib', 'PERHEXILINE', 'LEVOSIMENDAN', 'Romidepsin', 'paclitaxel', 'Sumanirole', 'naratriptan', 'MEGESTROL ACETATE', 'MOXONIDINE', 'Eltrombopag', 'Osanetant', 'azathioprine', 'Pioglitazone', 'hydrochlorothiazide', 'VX-702', 'Foretinib', 'tenoxicam', 'pravastatin', 'theobromine', 'clonidine', 'Quizartinib', 'ABEXINOSTAT', 'AMILORIDE', 'CYPROHEPTADINE', 'norepinephrine', 'NPS-2143', 'naltrexone', 'Etomidate', 'Tivantinib', 'primidone', 'hydroxychloroquine', 'cyclobenzaprine', 'Nepafenac', 'Cediranib', 'Sonidegib', 'Lenalidomide', 'nimesulide', 'Canertinib', 'PONATINIB', 'propafenone', 'Macitentan', 'etodolac', 'cetirizine', 'ketoprofen', 'flurbiprofen', 'Sunitinib', 'Bardoxolone methyl', 'Nintedanib', 'gemfibrozil', 'Trilostane', 'suramin', 'geldanamycin', 'memantine', 'Emricasan', 'AT7519', 'Dofetilide', 'miconazole', 'Abiraterone', 'VARLITINIB', 'emodin', 'Imatinib', 'trazodone', 'Regorafenib', 'NIGULDIPINE', 'histamine', 'Pranlukast', 'mirtazapine', 'leflunomide', 'Tolvaptan', 'theophylline', 'Repaglinide', 'bethanechol', 'AZD8330', 'Ziprasidone', 'lonidamine', 'Ciprofibrate', 'trichlormethiazide', 'Linsitinib', 'phentolamine', 'terazosin', 'Baricitinib', 'Tideglusib', 'oxybutynin', 'gabexate', 'bumetanide', 'Fingolimod', 'pramipexole', 'tamoxifen', 'purvalanol A', 'Rilmenidine', 'Lenvatinib', 'ADL5859', 'Tesmilifene', 'mitotane', 'Glycyrrhizic acid', 'pentagastrin', 'sotalol', 'famotidine', 'gabapentin', 'Midostaurin', 'oxymetazoline', 'acetaminophen', 'ibuprofen', 'olanzapine', 'milrinone', 'carvedilol', 'Tamibarotene', 'Temsirolimus', 'Bosutinib', 'SERATRODAST', 'Ruxolitinib', 'Binimetinib', 'FLUTICASONE PROPIONATE', 'felbamate', 'trifluoperazine', 'PROCATEROL', 'doxazosin', 'Pomalidomide', 'haloperidol', 'Vatalanib', 'dopamine', 'tizanidine', 'phenoxybenzamine', 'Cladribine', 'clozapine', 'hexestrol', 'cilostazol', 'Fostamatinib', 'phenylephrine', 'RAF265', 'Cabozantinib', 'isradipine', 'amoxapine', 'citalopram']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 221 56

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#            Drug A       Drug B Cell Line Name Study Name      Score
# 0      paclitaxel    Sunitinib           ACHN    ALMANAC   5.671410
# 1      raloxifene   Vismodegib           HT29    ALMANAC  -4.762552
# 2        Axitinib   Vandetanib       UACC-257    ALMANAC   3.663130
# 3      Vismodegib     Axitinib       NCI-H522    ALMANAC   0.575967
# 4       Nilotinib  Enzastaurin       SK-MEL-5   FRIEDMAN -12.013209
# ...           ...          ...            ...        ...        ...
# 27300  raloxifene   Crizotinib        RXF 393    ALMANAC  -3.965202
# 27301  Crizotinib    Nilotinib        RXF 393    ALMANAC  -5.362582
# 27302  Crizotinib  Abiraterone            M14    ALMANAC   1.643903
# 27303   Sorafenib   Bexarotene       SK-MEL-5   FRIEDMAN   7.719935
# 27304  paclitaxel    Sunitinib       COLO 205    ALMANAC  -5.629454
#
# [27305 rows x 5 columns]
#            Drug A       Drug B Cell Line Name Study Name      Score
# 0     Ruxolitinib     mitotane        SK-OV-3    ALMANAC   5.202879
# 1       clozapine  Ruxolitinib         L-1236   NCATS_HL  -5.667262
# 2    Cabozantinib  Ruxolitinib         L-1236   NCATS_HL -25.523161
# 3          RAF265  Midostaurin        IPC-298   FRIEDMAN   3.692926
# 4      Tideglusib    Vatalanib          A101D   FRIEDMAN   5.124306
# ..            ...          ...            ...        ...        ...
# 471   Ruxolitinib     mitotane           HT29    ALMANAC   2.979199
# 472   Ruxolitinib  Midostaurin       SK-MEL-5   FRIEDMAN  -7.796935
# 473   Ruxolitinib   Tideglusib          WM115   FRIEDMAN  -9.205078
# 474    Fingolimod  Midostaurin           MeWo   FRIEDMAN  -1.991372
# 475   Ruxolitinib     mitotane         MOLT-4    ALMANAC   8.226067
#
# [476 rows x 5 columns]

# %% [markdown]
# ## 3.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)
# Out:
# 105
# ['LOVO', 'HCT-15', 'SK-MEL-2', 'EKVX', 'TK-10', 'Mel Ho', 'A2780', 'L-1236', 'RXF 393', 'UACC-257', 'HCC1419', 'OCUBM', 'HCC-2998', 'SK-MEL-28', 'SK-MEL-5', 'SR', 'RPMI-8226', 'A2058', 'DU-145', 'CAOV3', 'MeWo', 'LOX IMVI', 'UACC-812', 'PA1', 'BT-474', 'A549', 'IST-MEL1', 'HOP-62', 'L-428', 'IPC-298', 'HT29', 'NCIH520', 'HT144', 'MDA-MB-231', 'MOLT-4', 'G-361', 'SKMEL30', 'OVCAR-5', 'HDLM-2', 'CCRF-CEM', 'HCC1500', 'MCF7', 'COLO 800', 'SW837', 'RKO', 'MDAMB436', 'HCT116', 'T-47D', 'ACHN', 'SKMES1', 'MMAc-SF', 'U251', 'PC-3', 'Huh-7', 'MZ-MEL-7', '451Lu', 'COLO 792', 'SN12C', '786-0', 'OVCAR-4', 'NCI-H226', 'SF-539', 'SK-OV-3', 'RVH-421', 'RPMI7951', 'VCAP', 'NCI-H522', 'BT-549', 'NCI-H460', 'CAKI-1', 'MDA-MB-175-VII', 'MDA-MB-468', 'KM12', 'A498', 'OVCAR3', 'SNB-75', 'MDA-MB-361', 'NCIH1650', 'IGROV1', 'CAMA-1', 'OV90', 'UACC62', 'COLO 205', 'SW-620', 'A375', 'MZ-MEL-2', 'NCIH2122', 'OVCAR-8', 'WM115', 'A101D', 'NCIH23', 'UWB1289', 'HOP-92', 'SF-295', 'NCI-H322M', 'SF-268', 'WT2-iPS', 'HS 578T', 'COLO 829', 'RD', 'LB2518-MEL', 'K-562', 'UO-31', 'M14', 'A427']

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))
# Out:
# 84 21

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#             Drug A       Drug B Cell Line Name Study Name      Score
# 0       paclitaxel    Sunitinib           ACHN    ALMANAC   5.671410
# 1       raloxifene   Vismodegib           HT29    ALMANAC  -4.762552
# 2         Axitinib   Vandetanib       UACC-257    ALMANAC   3.663130
# 3       Vismodegib     Axitinib       NCI-H522    ALMANAC   0.575967
# 4        Nilotinib  Enzastaurin       SK-MEL-5   FRIEDMAN -12.013209
# ...            ...          ...            ...        ...        ...
# 21914  Abiraterone   raloxifene         OVCAR3    ALMANAC  -1.104269
# 21915   raloxifene   Crizotinib        RXF 393    ALMANAC  -3.965202
# 21916   Crizotinib    Nilotinib        RXF 393    ALMANAC  -5.362582
# 21917    Sorafenib   Bexarotene       SK-MEL-5   FRIEDMAN   7.719935
# 21918   paclitaxel    Sunitinib       COLO 205    ALMANAC  -5.629454
#
# [21919 rows x 5 columns]
#            Drug A        Drug B Cell Line Name Study Name      Score
# 0     Ruxolitinib    Vandetanib          UO-31    ALMANAC   1.893364
# 1      Fingolimod    Crizotinib       COLO 829   FRIEDMAN   3.159402
# 2      Crizotinib   Abiraterone         SF-268    ALMANAC   7.183144
# 3       Sorafenib   Palbociclib     LB2518-MEL   FRIEDMAN -19.263679
# 4          VX-702     Vatalanib          WM115   FRIEDMAN   0.684091
# ...           ...           ...            ...        ...        ...
# 5857    Nilotinib  Lenalidomide        WT2-iPS   FRIEDMAN  -4.152064
# 5858    Dasatinib    Vorinostat       MZ-MEL-2   FRIEDMAN -18.833992
# 5859    Gefitinib     Nilotinib        OVCAR-8    ALMANAC  -4.116473
# 5860   Vismodegib      mitotane        OVCAR-8    ALMANAC   1.012335
# 5861   Crizotinib   Abiraterone            M14    ALMANAC   1.643903
#
# [5862 rows x 5 columns]

# %% [markdown]
# # 4. DrugCombDB

# %% [markdown]
# ## 4.1 Mask some drugs

# %%
import pandas as pd
import numpy as np
dataset = 'data-DrugCombDB'
random_final_input_df = pd.read_csv('./' + dataset + '/filtered_data/random_final_dl_input.csv')
random_final_input_df
# Out:
#              Drug A            Drug B Cell Line Name    Score
# 0       VEMURAFENIB          IMATINIB          HT-29 -17.9000
# 1         DASATINIB       FULVESTRANT       NCI-H460  -2.5500
# 2       VEMURAFENIB         LAPATINIB         Caki-1   5.0800
# 3      MIFEPRISTONE       RUXOLITINIB         L-1236 -28.8310
# 4          AXITINIB       FULVESTRANT     MDA-MB-231  -8.9100
# ...             ...               ...            ...      ...
# 21394     DASATINIB         SORAFENIB          A-375  11.3075
# 21395     TRETINOIN         DASATINIB        SK-OV-3   1.9000
# 21396     SUNITINIB  ARSENIC TRIOXIDE           ACHN  -3.0600
# 21397   RUXOLITINIB          IMATINIB        U-251MG  -1.5500
# 21398     NILOTINIB          MITOTANE          T-47D  -4.3900
#
# [21399 rows x 4 columns]

# %%
# Combine sets of both columns to get unique drugs
unique_drug_list = sorted(list(set(random_final_input_df['Drug A']).union(set(random_final_input_df['Drug B']))))
np.random.shuffle(unique_drug_list)
print(unique_drug_list)
# Out:
# ['YOHIMBINE', 'PANOBINOSTAT', 'ESTRAMUSTINE', 'VEMURAFENIB', 'PACLITAXEL', 'ABEXINOSTAT', 'BARICITINIB', 'GEFITINIB', 'RAMIPRIL', 'CISPLATIN', 'TRILOSTANE', 'SYNEPHRINE', 'MELATONIN', 'LENALIDOMIDE', 'PALBOCICLIB', 'MELOXICAM', 'ARGATROBAN', 'GLIPIZIDE', 'INDOMETHACIN', 'SALBUTAMOL', 'ACETAMINOPHEN', 'FORETINIB', 'CONIVAPTAN', 'PRACINOSTAT', 'AMOXAPINE', 'BISOPROLOL', 'ERLOTINIB', 'STREPTOZOCIN', 'THEOBROMINE', 'IMATINIB', 'NIFLUMIC ACID', 'GW501516', 'MEDROXYPROGESTERONE ACETATE', 'BARDOXOLONE METHYL', 'WORTMANNIN', 'DIMETHYL FUMARATE', 'ALMOTRIPTAN', 'LINSITINIB', 'GENISTEIN', 'GOSSYPOL', 'LANSOPRAZOLE', 'PH797804', 'IBUPROFEN', 'HISTAMINE', 'VINBLASTINE', 'DOBUTAMINE', 'APREPITANT', 'MICONAZOLE', 'NILOTINIB', 'EMRICASAN', 'MOXONIDINE', 'HALOPERIDOL', 'CABOZANTINIB', 'OSI930', 'ANAGRELIDE', 'FLUOCINONIDE', 'SPERMIDINE', 'CYC116', 'KETOTIFEN', 'SERATRODAST', 'PERIFOSINE', 'RIZATRIPTAN', 'ANDROGRAPHOLIDE', 'ADAPALENE', 'MINOCYCLINE', 'FLUPIRTINE', 'AMBRISENTAN', 'GABEXATE', 'DIGOXIN', 'SORAFENIB', 'LAPATINIB', 'FELBAMATE', 'TESTOSTERONE', 'TANDUTINIB', 'ROXADUSTAT', 'MESTRANOL', 'FULVESTRANT', 'RISPERIDONE', 'CARVEDILOL', 'CERULENIN', 'OXYBUTYNIN', 'MEGESTROL ACETATE', 'RHEIN', 'GEMFIBROZIL', 'MIANSERIN', 'NAPROXEN', 'OXYMETAZOLINE', 'CAFFEINE', 'DYPHYLLINE', 'TAMOXIFEN', 'ENZASTAURIN', 'ARIPIPRAZOLE', 'ZIPRASIDONE', 'TALMAPIMOD', 'MECLIZINE', 'BAZEDOXIFENE', 'CANERTINIB', 'ARTENIMOL', 'DIETHYLSTILBESTROL', 'GLICLAZIDE', 'PURVALANOL A', 'NAFAMOSTAT', 'TRAMETINIB', 'CLONIDINE', 'DOFETILIDE', 'SULFASALAZINE', 'ROFECOXIB', 'LORNOXICAM', 'VERAPAMIL', 'NINTEDANIB', 'DOCETAXEL', 'MITOTANE', 'ESTRIOL', 'MOCETINOSTAT', 'NOREPINEPHRINE', 'MEMANTINE', 'LAMOTRIGINE', 'AMISULPRIDE', 'MARAVIROC', 'LY2140023', 'BELINOSTAT', 'BETAXOLOL', 'KETANSERIN', 'ELLAGIC ACID', 'PHENOXYBENZAMINE', 'CIPROFIBRATE', 'TETRABENAZINE', 'AT7519', 'ACITRETIN', 'PROGESTERONE', 'TAURINE', 'CEDIRANIB', 'ONDANSETRON', 'FOMEPIZOLE', 'BUFEXAMAC', 'ALPROSTADIL', 'QUIZARTINIB', 'PAPAVERINE', 'TEMSIROLIMUS', 'GLYCYRRHIZIC ACID', 'CLADRIBINE', 'CRIZOTINIB', 'VISMODEGIB', 'ERTEBEREL', 'COBIMETINIB', 'DIENESTROL', 'OBATOCLAX', 'FENOLDOPAM', 'ROLIPRAM', 'SNX5422', 'FENOFIBRATE', 'GABAPENTIN', 'RILMENIDINE', 'CITALOPRAM', 'IVACAFTOR', 'RIFABUTIN', 'AZELASTINE', 'FLURBIPROFEN', 'SURAMIN', 'AXITINIB', 'ILOPERIDONE', 'TRAZODONE', 'PLERIXAFOR', 'SULPIRIDE', 'FLUPHENAZINE', 'CINACALCET', 'TIZANIDINE', 'ESTRADIOL', 'OSANETANT', 'SNS032', 'TOLVAPTAN', 'INGENOL MEBUTATE', 'LUMACAFTOR', 'QUERCETIN', 'BEXAROTENE', 'SCOPOLAMINE', 'FAMOTIDINE', 'MK0354', 'ALFUZOSIN', 'ARECOLINE', 'METFORMIN', 'SUMANIROLE', 'AFATINIB', 'AMLEXANOX', 'BETHANECHOL', 'TANESPIMYCIN', 'EPINEPHRINE', 'XIMELAGATRAN', 'FINGOLIMOD', 'AURANOFIN', 'BAFILOMYCIN A1', 'PIOGLITAZONE', 'NATEGLINIDE', 'AMILORIDE', 'VARLITINIB', 'IMEXON', 'PHENYLEPHRINE', 'CICLOPIROX', 'DABRAFENIB', 'FASUDIL', 'DROSPIRENONE', 'SONIDEGIB', 'CILOSTAZOL', 'TRAVOPROST', 'BALSALAZIDE', 'MIRTAZAPINE', 'VATALANIB', 'OLANZAPINE', 'PRANLUKAST', 'LORATADINE', 'FLUTICASONE PROPIONATE', 'NIACIN', 'DASATINIB', 'RUXOLITINIB', 'LEFLUNOMIDE', 'SUNITINIB', 'SILODOSIN', 'THEOPHYLLINE', 'TG100115', 'DOMPERIDONE', 'CELECOXIB', 'TELMISARTAN', 'ROSIGLITAZONE', 'TRICHLORMETHIAZIDE', 'TESTOSTERONE CYPIONATE', 'LEVOSIMENDAN', 'MACITENTAN', 'MAPROTILINE', 'KETOROLAC', 'CLOMIPRAMINE', 'LOVASTATIN', 'ESTRONE', 'OLMESARTAN', 'DOPAMINE', 'FLUNARIZINE', 'GELDANAMYCIN', 'MANIDIPINE', 'PRAVASTATIN', 'MYRICETIN', 'PELITINIB', 'LONIDAMINE', 'AMUVATINIB', 'PENTAGASTRIN', 'LEVONORGESTREL', 'SIMVASTATIN', 'METHYLDOPA', 'ORPHENADRINE', 'LENVATINIB', 'HYDROXYCHLOROQUINE', 'PRAMIPEXOLE', 'CHLOROQUINE', 'PIBOSEROD', 'EMODIN', 'DAPOXETINE', 'VORAPAXAR', 'SIROLIMUS', 'SOTALOL', 'AV412', 'LICOFELONE', 'RIDAFOROLIMUS', 'RIMONABANT', 'AMIODARONE', 'ROFLUMILAST', 'TAZAROTENE', 'OCTREOTIDE', 'ADENOSINE', 'NEPAFENAC', 'POMALIDOMIDE', 'PAZOPANIB', 'KX01', 'MILRINONE', 'PRUCALOPRIDE', 'MIDOSTAURIN', 'RESVERATROL', 'DIPHENHYDRAMINE', 'DRONEDARONE', 'DIENOGEST', 'XYLOMETAZOLINE', 'NERATINIB' ...

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_drug_list) * 0.8)

# Split the list into 80% and 20%
drugs_train_percent = unique_drug_list[:split_index]
drugs_test_percent = unique_drug_list[split_index:]
print(len(drugs_train_percent), len(drugs_test_percent))
# Out:
# 305 77

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_train_percent) | random_final_input_df['Drug B'].isin(drugs_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Drug A'].isin(drugs_test_percent) & random_final_input_df['Drug B'].isin(drugs_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
# Out:
#              Drug A            Drug B Cell Line Name    Score
# 0       VEMURAFENIB          IMATINIB          HT-29 -17.9000
# 1         DASATINIB       FULVESTRANT       NCI-H460  -2.5500
# 2       VEMURAFENIB         LAPATINIB         Caki-1   5.0800
# 3      MIFEPRISTONE       RUXOLITINIB         L-1236 -28.8310
# 4          AXITINIB       FULVESTRANT     MDA-MB-231  -8.9100
# ...             ...               ...            ...      ...
# 20099     DASATINIB         SORAFENIB          A-375  11.3075
# 20100     TRETINOIN         DASATINIB        SK-OV-3   1.9000
# 20101     SUNITINIB  ARSENIC TRIOXIDE           ACHN  -3.0600
# 20102   RUXOLITINIB          IMATINIB        U-251MG  -1.5500
# 20103     NILOTINIB          MITOTANE          T-47D  -4.3900
#
# [20104 rows x 4 columns]
#            Drug A            Drug B Cell Line Name  Score
# 0      RALOXIFENE       THALIDOMIDE          HT-29  -0.66
# 1     ABIRATERONE        VANDETANIB        OVCAR-5  -1.33
# 2       TRETINOIN        ROMIDEPSIN          SN12C -52.23
# 3      RALOXIFENE        VANDETANIB         Caki-1  -8.28
# 4      VANDETANIB        RALOXIFENE         HOP-62   6.64
# ...           ...               ...            ...    ...
# 1290  ABIRATERONE        VANDETANIB           PC-3  -3.94
# 1291  ABIRATERONE        ROMIDEPSIN     MDA-MB-468 -31.15
# 1292   ROMIDEPSIN  ARSENIC TRIOXIDE          DU145  -3.97
# 1293   VANDETANIB        ROMIDEPSIN           KM12 -73.23
# 1294   RALOXIFENE  ARSENIC TRIOXIDE      RPMI-8226   1.04
#
# [1295 rows x 4 columns]

# %% [markdown]
# ## 4.2 Mask some cell lines

# %%
# Combine sets of both columns to get unique drugs
unique_cellline_list = sorted(list(set(random_final_input_df['Cell Line Name'])))
np.random.shuffle(unique_cellline_list)
print(len(unique_cellline_list))
print(unique_cellline_list)

# %%
# Splitting drug combinations into 80% and 20%
# Calculate the split index for 80% of the list
split_index = int(len(unique_cellline_list) * 0.8)

# Split the list into 80% and 20%
cellline_train_percent = unique_cellline_list[:split_index]
cellline_test_percent = unique_cellline_list[split_index:]
print(len(cellline_train_percent), len(cellline_test_percent))

# %%
# Filtering DataFrame by 80% cell lines
df_train_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_train_percent)]
df_train_percent = df_train_percent.reset_index(drop=True)

# Filtering DataFrame by 20% cell lines
df_test_percent = random_final_input_df[random_final_input_df['Cell Line Name'].isin(cellline_test_percent)]
df_test_percent = df_test_percent.reset_index(drop=True)

display(df_train_percent)
display(df_test_percent)
df_train_percent.to_csv('./' + dataset + '/filtered_data/split_input_1.csv', index=False)
df_test_percent.to_csv('./' + dataset + '/filtered_data/split_input_2.csv', index=False)
