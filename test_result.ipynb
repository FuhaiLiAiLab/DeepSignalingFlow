# %% [markdown]
# # 1. NCI ALMANAC

# %% [markdown]
# ## 1.1 NCI ALMANAC Pearson Correlation

# %%
xgboost_test_list = [0.636280, 0.607164, 0.621125, 0.562870, 0.547934]
rf_test_list = [0.669306, 0.635840, 0.652682, 0.569410, 0.590657]
gcn_decoder_test_list = [0.4130003816635538, 0.4662483372799231, 0.5370335322761259, 0.4194793977603401, 0.40824100173344124]
gat_decoder_test_list = [0.26376485906231467, 0.2848270231318383, 0.13984699396293215, 0.10261948454381241, 0.22744885730348186]
gformer_decoder_test_list = [0.3401364920237653, 0.450464128651303, 0.3210135831806914, 0.3603290521749046, 0.34775804415504713]
mixhop_decoder_test_list = [0.5543345142484409, 0.553354672766029, 0.5530773338442082, 0.551463043350704, 0.19403301031027562]
gin_decoder_test_list = [0.5346631585350167, 0.5355933804574946, 0.6135699971683238, 0.5148608612661582, 0.44817324371648787]
bgnn_decoder_test_list = [0.4119730693291053, 0.4682973863943678, 0.5833313570882066, 0.45037452486142593, 0.5021614819890272]
webgnn_decoder_test_list = [0.6397148600951211, 0.62665668248812, 0.6550570523219267, 0.6529237122532979, 0.6132623125813826]

# %%
# calculate the average and std of the test results 
import numpy as np
xgboost_avg = np.mean(xgboost_test_list)
xgboost_std = np.std(xgboost_test_list)
rf_avg = np.mean(rf_test_list)
rf_std = np.std(rf_test_list)

gcn_avg = np.mean(gcn_decoder_test_list)
gcn_std = np.std(gcn_decoder_test_list)
gat_avg = np.mean(gat_decoder_test_list)
gat_std = np.std(gat_decoder_test_list)
gformer_avg = np.mean(gformer_decoder_test_list)
gformer_std = np.std(gformer_decoder_test_list)
mixhop_avg = np.mean(mixhop_decoder_test_list)
mixhop_std = np.std(mixhop_decoder_test_list)
gin_avg = np.mean(gin_decoder_test_list)
gin_std = np.std(gin_decoder_test_list)
bgnn_avg = np.mean(bgnn_decoder_test_list)
bgnn_std = np.std(bgnn_decoder_test_list)
webgnn_avg = np.mean(webgnn_decoder_test_list)
webgnn_std = np.std(webgnn_decoder_test_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
import pandas as pd
xgboost_avg_str = "{:.2%}".format(xgboost_avg)
xgboost_std_str = "{:.2%}".format(xgboost_std)
rf_avg_str = "{:.2%}".format(rf_avg)
rf_std_str = "{:.2%}".format(rf_std)
gcn_avg_str = "{:.2%}".format(gcn_avg)
gcn_std_str = "{:.2%}".format(gcn_std)
gat_avg_str = "{:.2%}".format(gat_avg)
gat_std_str = "{:.2%}".format(gat_std)
gformer_avg_str = "{:.2%}".format(gformer_avg)
gformer_std_str = "{:.2%}".format(gformer_std)
mixhop_avg_str = "{:.2%}".format(mixhop_avg)
mixhop_std_str = "{:.2%}".format(mixhop_std)
gin_avg_str = "{:.2%}".format(gin_avg)
gin_std_str = "{:.2%}".format(gin_std)
bgnn_avg_str = "{:.2%}".format(bgnn_avg)
bgnn_std_str = "{:.2%}".format(bgnn_std)
webgnn_avg_str = "{:.2%}".format(webgnn_avg)
webgnn_std_str = "{:.2%}".format(webgnn_std)
nci_model_comparison_table = pd.DataFrame({"avg":[xgboost_avg_str, rf_avg_str, gcn_avg_str, gat_avg_str, gformer_avg_str, mixhop_avg_str, gin_avg_str, bgnn_avg_str, webgnn_avg_str], 
                                       "std":[xgboost_std_str, rf_std_str, gcn_std_str, gat_std_str, gformer_std_str, mixhop_std_str, gin_std_str, bgnn_std_str, webgnn_std_str]}, 
                                       index=["XGBOOST", "RANDOM-FOREST",  "GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])
display(nci_model_comparison_table)
# Out:
#                   avg     std
# XGBOOST        59.51%   3.40%
# RANDOM-FOREST  62.36%   3.77%
# GCN            44.88%   4.87%
# GAT            20.37%   7.08%
# GFORMER        36.39%   4.51%
# MIXHOP         48.13%  14.36%
# GIN            52.94%   5.28%
# BGNN           48.32%   5.79%
# WEBGNN         63.75%   1.58%

# %% [markdown]
# ## 1.2 NCI ALMANAC MSE Loss

# %%
gcn_decoder_loss_list = [63.902451129972334, 59.84223257788887, 47.65978572242371, 54.72651598817428, 62.59031922493993]
gat_decoder_loss_list = [71.5896329874924, 68.95223543950691, 66.04381051331788, 67.79175028848702, 77.0747565202253]
gformer_decoder_loss_list = [67.99761877722027, 59.875495413797104, 58.83025552948033, 57.58873683392526, 67.07990556102031]
mixhop_decoder_loss_list = [53.62175310547496, 52.03032547537745, 52.578799063811665, 52.19547108464143, 226.59517045997794]
gin_decoder_loss_list = [55.01248180888965, 53.78410330893814, 40.734818957343776, 48.66515609709356, 59.68184453559086]
bgnn_decoder_loss_list = [64.00783180261408, 58.727385051982324, 43.93283572151008, 53.41115326350556, 56.81062347325488]
webgnn_decoder_loss_list = [45.75867400297961, 46.52323556732995, 37.32807489385413, 37.71835076666847, 48.48082280933184]

# %%
# calculate the average and std of the loss results
gcn_avg_loss = np.mean(gcn_decoder_loss_list)
gcn_std_loss = np.std(gcn_decoder_loss_list)
gat_avg_loss = np.mean(gat_decoder_loss_list)
gat_std_loss = np.std(gat_decoder_loss_list)
gformer_avg_loss = np.mean(gformer_decoder_loss_list)
gformer_std_loss = np.std(gformer_decoder_loss_list)
mixhop_avg_loss = np.mean(mixhop_decoder_loss_list)
mixhop_std_loss = np.std(mixhop_decoder_loss_list)
gin_avg_loss = np.mean(gin_decoder_loss_list)
gin_std_loss = np.std(gin_decoder_loss_list)
bgnn_avg_loss = np.mean(bgnn_decoder_loss_list)
bgnn_std_loss = np.std(bgnn_decoder_loss_list)
webgnn_avg_loss = np.mean(webgnn_decoder_loss_list)
webgnn_std_loss = np.std(webgnn_decoder_loss_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
gcn_avg_loss_str = "{:.4}".format(gcn_avg_loss)
gcn_std_loss_str = "{:.4}".format(gcn_std_loss)
gat_avg_loss_str = "{:.4}".format(gat_avg_loss)
gat_std_loss_str = "{:.4}".format(gat_std_loss)
gformer_avg_loss_str = "{:.4}".format(gformer_avg_loss)
gformer_std_loss_str = "{:.4}".format(gformer_std_loss)
mixhop_avg_loss_str = "{:.4}".format(mixhop_avg_loss)
mixhop_std_loss_str = "{:.4}".format(mixhop_std_loss)
gin_avg_loss_str = "{:.4}".format(gin_avg_loss)
gin_std_loss_str = "{:.4}".format(gin_std_loss)
bgnn_avg_loss_str = "{:.4}".format(bgnn_avg_loss)
bgnn_std_loss_str = "{:.4}".format(bgnn_std_loss)
webgnn_avg_loss_str = "{:.4}".format(webgnn_avg_loss)
webgnn_std_loss_str = "{:.4}".format(webgnn_std_loss)

nci_model_comparison_table_loss = pd.DataFrame({"avg":[gcn_avg_loss_str, gat_avg_loss_str, gformer_avg_loss_str, mixhop_avg_loss_str, gin_avg_loss_str, bgnn_avg_loss_str, webgnn_avg_loss_str],
                                            "std":[gcn_std_loss_str, gat_std_loss_str, gformer_std_loss_str, mixhop_std_loss_str, gin_std_loss_str, bgnn_std_loss_str, webgnn_std_loss_str]},
                                           index=["GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])
display(nci_model_comparison_table_loss)
# Out:
#            avg    std
# GCN      57.74  5.943
# GAT      70.29  3.841
# GFORMER  62.27  4.369
# MIXHOP    87.4   69.6
# GIN      51.58  6.456
# BGNN     55.38  6.672
# WEBGNN   43.16   4.69

# %% [markdown]
# # 2. ONEIL

# %% [markdown]
# ## 2.1 ONEIL Pearson Correlation

# %%
xgboost_test_list = [0.678435, 0.633401, 0.638970, 0.660978, 0.693886]
rf_test_list = [0.678316, 0.685238, 0.665807, 0.708294, 0.677736]
gcn_decoder_test_list = [0.41033774433685655, 0.41238576688957074, 0.5197152727755879, 0.6265475866754472, 0.5342658587375002]
gat_decoder_test_list = [0.47572474192387526, 0.06893487590156398, 0.44111973137933025, 0.21029094901113685, 0.3811419810883614]
gformer_decoder_test_list = [0.2713893427081094, 0.21219459595575807, 0.42128108095074707, 0.45728565163651524, 0.07074770191061115]
mixhop_decoder_test_list = [0.0772987028887031, 0.07128515265480145, 0.1551026748912726, 0.04272932358065324, 0.0002577887499931987]
gin_decoder_test_list = [0.18812599794165918, 0.1733832212389168, 0.2460039719862855, 0.40974219670524653, 0.1497926428982809]
bgnn_decoder_test_list = [0.6111242129200846, 0.5997977875104633, 0.568276750200448, 0.6618640856860075, 0.627028074217642]
webgnn_decoder_test_list = [0.6710612105275339, 0.6219820023140109, 0.6265848478536921, 0.6903138630310607, 0.6807606739300186]

# %%
# calculate the average and std of the test results
xgboost_avg = np.mean(xgboost_test_list)
xgboost_std = np.std(xgboost_test_list)
rf_avg = np.mean(rf_test_list)
rf_std = np.std(rf_test_list)
gcn_avg = np.mean(gcn_decoder_test_list)
gcn_std = np.std(gcn_decoder_test_list)
gat_avg = np.mean(gat_decoder_test_list)
gat_std = np.std(gat_decoder_test_list)
gformer_avg = np.mean(gformer_decoder_test_list)
gformer_std = np.std(gformer_decoder_test_list)
mixhop_avg = np.mean(mixhop_decoder_test_list)
mixhop_std = np.std(mixhop_decoder_test_list)
gin_avg = np.mean(gin_decoder_test_list)
gin_std = np.std(gin_decoder_test_list)
bgnn_avg = np.mean(bgnn_decoder_test_list)
bgnn_std = np.std(bgnn_decoder_test_list)
webgnn_avg = np.mean(webgnn_decoder_test_list)
webgnn_std = np.std(webgnn_decoder_test_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
xgboost_avg_str = "{:.2%}".format(xgboost_avg)
xgboost_std_str = "{:.2%}".format(xgboost_std)
rf_avg_str = "{:.2%}".format(rf_avg)
rf_std_str = "{:.2%}".format(rf_std)
gcn_avg_str = "{:.2%}".format(gcn_avg)
gcn_std_str = "{:.2%}".format(gcn_std)
gat_avg_str = "{:.2%}".format(gat_avg)
gat_std_str = "{:.2%}".format(gat_std)
gformer_avg_str = "{:.2%}".format(gformer_avg)
gformer_std_str = "{:.2%}".format(gformer_std)
mixhop_avg_str = "{:.2%}".format(mixhop_avg)
mixhop_std_str = "{:.2%}".format(mixhop_std)
gin_avg_str = "{:.2%}".format(gin_avg)
gin_std_str = "{:.2%}".format(gin_std)
bgnn_avg_str = "{:.2%}".format(bgnn_avg)
bgnn_std_str = "{:.2%}".format(bgnn_std)
webgnn_avg_str = "{:.2%}".format(webgnn_avg)
webgnn_std_str = "{:.2%}".format(webgnn_std)

oneil_model_comparison_table = pd.DataFrame({"avg":[xgboost_avg_str, rf_avg_str, gcn_avg_str, gat_avg_str, gformer_avg_str, mixhop_avg_str, gin_avg_str, bgnn_avg_str, webgnn_avg_str],
                                            "std":[xgboost_std_str, rf_std_str, gcn_std_str, gat_std_str, gformer_std_str, mixhop_std_str, gin_std_str, bgnn_std_str, webgnn_std_str]},
                                           index=["XGBOOST", "RANDOM-FOREST",  "GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])

display(oneil_model_comparison_table)
# Out:
#                   avg     std
# XGBOOST        66.11%   2.29%
# RANDOM-FOREST  68.31%   1.41%
# GCN            50.07%   8.16%
# GAT            31.54%  15.34%
# GFORMER        28.66%  14.12%
# MIXHOP          6.93%   5.08%
# GIN            23.34%   9.37%
# BGNN           61.36%   3.09%
# WEBGNN         65.81%   2.83%

# %% [markdown]
# ## 2.2 ONEIL MSE Loss

# %%
gcn_decoder_loss_list = [228.45041484799478, 249.4418086649337, 189.07698256868807, 160.5891013471886, 210.61989773059162]
gat_decoder_loss_list = [203.2219590977223, 735.2568149021514, 206.90585741692206, 256.2787857677217, 251.9326012305425]
gformer_decoder_loss_list = [325.72797331232545, 872.482740298472, 366.78564036441725, 210.65500191696498, 137649.77122838364]
mixhop_decoder_loss_list = [4124330.82507459, 585294.5508568499, 1417622.276024133, 2581585.4486690126, 534066.3596997794]
gin_decoder_loss_list = [14701.866385770223, 395.69572675152295, 263.54300471402905, 234.2129360393973, 1139.042754824849]
bgnn_decoder_loss_list = [165.23176278239154, 192.84218642752356, 175.22567782738463, 148.33201596695778, 180.2446320513897]
webgnn_decoder_loss_list = [146.32462728428632, 186.00472071378135, 158.73131455959052, 138.87934499279018, 158.77004669790713]

# %%
# calculate the average and std of the loss results
gcn_avg_loss = np.mean(gcn_decoder_loss_list)
gcn_std_loss = np.std(gcn_decoder_loss_list)
gat_avg_loss = np.mean(gat_decoder_loss_list)
gat_std_loss = np.std(gat_decoder_loss_list)
gformer_avg_loss = np.mean(gformer_decoder_loss_list)
gformer_std_loss = np.std(gformer_decoder_loss_list)
mixhop_avg_loss = np.mean(mixhop_decoder_loss_list)
mixhop_std_loss = np.std(mixhop_decoder_loss_list)
gin_avg_loss = np.mean(gin_decoder_loss_list)
gin_std_loss = np.std(gin_decoder_loss_list)
bgnn_avg_loss = np.mean(bgnn_decoder_loss_list)
bgnn_std_loss = np.std(bgnn_decoder_loss_list)
webgnn_avg_loss = np.mean(webgnn_decoder_loss_list)
webgnn_std_loss = np.std(webgnn_decoder_loss_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
gcn_avg_loss_str = "{:.4}".format(gcn_avg_loss)
gcn_std_loss_str = "{:.4}".format(gcn_std_loss)
gat_avg_loss_str = "{:.4}".format(gat_avg_loss)
gat_std_loss_str = "{:.4}".format(gat_std_loss)
gformer_avg_loss_str = "{:.4}".format(gformer_avg_loss)
gformer_std_loss_str = "{:.4}".format(gformer_std_loss)
mixhop_avg_loss_str = "{:.4}".format(mixhop_avg_loss)
mixhop_std_loss_str = "{:.4}".format(mixhop_std_loss)
gin_avg_loss_str = "{:.4}".format(gin_avg_loss)
gin_std_loss_str = "{:.4}".format(gin_std_loss)
bgnn_avg_loss_str = "{:.4}".format(bgnn_avg_loss)
bgnn_std_loss_str = "{:.4}".format(bgnn_std_loss)
webgnn_avg_loss_str = "{:.4}".format(webgnn_avg_loss)
webgnn_std_loss_str = "{:.4}".format(webgnn_std_loss)

oneil_model_comparison_table_loss = pd.DataFrame({"avg":[gcn_avg_loss_str, gat_avg_loss_str, gformer_avg_loss_str, mixhop_avg_loss_str, gin_avg_loss_str, bgnn_avg_loss_str, webgnn_avg_loss_str],
                                            "std":[gcn_std_loss_str, gat_std_loss_str, gformer_std_loss_str, mixhop_std_loss_str, gin_std_loss_str, bgnn_std_loss_str, webgnn_std_loss_str]},
                                            index=["GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])

display(oneil_model_comparison_table_loss)
# Out:
#                avg        std
# GCN          207.6      30.81
# GAT          330.7      203.5
# GFORMER  2.789e+04  5.488e+04
# MIXHOP   1.849e+06  1.358e+06
# GIN      3.347e+03  5.687e+03
# BGNN         172.4      14.95
# WEBGNN       157.7      16.04

# %% [markdown]
# # 3. DrugComb-fi

# %% [markdown]
# ## 3.1 DrugComb-fi Pearson Correlation

# %%
xgboost_test_list = [0.555848, 0.558369, 0.530912, 0.557552, 0.553214]
rf_boost_test_list = [0.652296, 0.652927, 0.648258, 0.652175, 0.658323]
gcn_decoder_test_list = [0.4394381949052708, 0.47542356835003174, 0.45337862650174626, 0.46821934067541665, 0.48377431876009747]
gat_decoder_test_list = [0.2680518009694834, 0.2992143148274788, 0.3109819503136837, 0.43470256538803353, 0.26730419562775054]
gformer_decoder_test_list = [0.5366301723117398, 0.4917373798921312, 0.5158106571947688, 0.5279677425166557, 0.5523108041425029]
mixhop_decoder_test_list = [0.4758458191530779, 0.4189757314617253, 0.4966532327304689, 0.4701113726317459, 0.4770144532869969]
gin_decoder_test_list = [0.22906986900579415, 0.2957402142164849, 0.12103488844122484, 0.47529572346642796, 0.47659591011350844]
bgnn_decoder_test_list = [0.5588727671056126, 0.5611288932225303, 0.5497078419253681, 0.5605375875205295, 0.5372897797577126]
webgnn_decoder_test_list = [0.6521754726510851, 0.6332060897475223, 0.6316243566643028, 0.6416298140702681, 0.625581701294117]

# %%
# calculate the average and std of the test results
xgboost_avg = np.mean(xgboost_test_list)
xgboost_std = np.std(xgboost_test_list)
rf_boost_avg = np.mean(rf_boost_test_list)
rf_boost_std = np.std(rf_boost_test_list)
gcn_avg = np.mean(gcn_decoder_test_list)
gcn_std = np.std(gcn_decoder_test_list)
gat_avg = np.mean(gat_decoder_test_list)
gat_std = np.std(gat_decoder_test_list)
gformer_avg = np.mean(gformer_decoder_test_list)
gformer_std = np.std(gformer_decoder_test_list)
mixhop_avg = np.mean(mixhop_decoder_test_list)
mixhop_std = np.std(mixhop_decoder_test_list)
gin_avg = np.mean(gin_decoder_test_list)
gin_std = np.std(gin_decoder_test_list)
bgnn_avg = np.mean(bgnn_decoder_test_list)
bgnn_std = np.std(bgnn_decoder_test_list)
webgnn_avg = np.mean(webgnn_decoder_test_list)
webgnn_std = np.std(webgnn_decoder_test_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
xgboost_avg_str = "{:.2%}".format(xgboost_avg)
xgboost_std_str = "{:.2%}".format(xgboost_std)
rf_boost_avg_str = "{:.2%}".format(rf_boost_avg)
rf_boost_std_str = "{:.2%}".format(rf_boost_std)
gcn_avg_str = "{:.2%}".format(gcn_avg)
gcn_std_str = "{:.2%}".format(gcn_std)
gat_avg_str = "{:.2%}".format(gat_avg)
gat_std_str = "{:.2%}".format(gat_std)
gformer_avg_str = "{:.2%}".format(gformer_avg)
gformer_std_str = "{:.2%}".format(gformer_std)
mixhop_avg_str = "{:.2%}".format(mixhop_avg)
mixhop_std_str = "{:.2%}".format(mixhop_std)
gin_avg_str = "{:.2%}".format(gin_avg)
gin_std_str = "{:.2%}".format(gin_std)
bgnn_avg_str = "{:.2%}".format(bgnn_avg)
bgnn_std_str = "{:.2%}".format(bgnn_std)
webgnn_avg_str = "{:.2%}".format(webgnn_avg)
webgnn_std_str = "{:.2%}".format(webgnn_std)

drugcombfi_model_comparison_table = pd.DataFrame({"avg":[xgboost_avg_str, rf_boost_avg_str, gcn_avg_str, gat_avg_str, gformer_avg_str, mixhop_avg_str, gin_avg_str, bgnn_avg_str, webgnn_avg_str],
                                            "std":[xgboost_std_str, rf_boost_std_str, gcn_std_str, gat_std_str, gformer_std_str, mixhop_std_str, gin_std_str, bgnn_std_str, webgnn_std_str]},
                                            index=["XGBOOST", "RANDOM-FOREST",  "GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])
display(drugcombfi_model_comparison_table)
# Out:
#                   avg     std
# XGBOOST        55.12%   1.03%
# RANDOM-FOREST  65.28%   0.32%
# GCN            46.40%   1.58%
# GAT            31.61%   6.18%
# GFORMER        52.49%   2.04%
# MIXHOP         46.77%   2.60%
# GIN            31.95%  13.93%
# BGNN           55.35%   0.91%
# WEBGNN         63.68%   0.92%

# %% [markdown]
# ## 3.2 DrugComb-fi MSE Loss

# %%
gcn_decoder_loss_list = [191.08113495749106, 183.46630158824706, 170.39829866215172, 188.59074704552458, 168.74869468090967]
gat_decoder_loss_list = [220.1930772305037, 214.77942341652923, 193.43760161123643, 195.85233609935506, 203.02609619004795]
gformer_decoder_loss_list = [169.82018817299928, 178.8790385564505, 158.71103485493117, 176.42127080817946, 151.86007009126487]
mixhop_decoder_loss_list = [184.70153910623168, 201.97908686943003, 162.2020565743042, 190.72263553971982, 170.13790762302168]
gin_decoder_loss_list = [225.57745432234938, 217.81293300305728, 919.3866048284583, 186.94309703341398, 168.96241533596745]
bgnn_decoder_loss_list = [163.52420727155229, 161.67173876974488, 149.13136082035248, 165.49620389947424, 155.39123297392345]
webgnn_decoder_loss_list = [136.45996144674268, 141.87456418064068, 129.40195719578657, 143.04182143026858, 134.68989931589664]

# %%
# calculate the average and std of the loss results
gcn_avg_loss = np.mean(gcn_decoder_loss_list)
gcn_std_loss = np.std(gcn_decoder_loss_list)
gat_avg_loss = np.mean(gat_decoder_loss_list)
gat_std_loss = np.std(gat_decoder_loss_list)
gformer_avg_loss = np.mean(gformer_decoder_loss_list)
gformer_std_loss = np.std(gformer_decoder_loss_list)
mixhop_avg_loss = np.mean(mixhop_decoder_loss_list)
mixhop_std_loss = np.std(mixhop_decoder_loss_list)
gin_avg_loss = np.mean(gin_decoder_loss_list)
gin_std_loss = np.std(gin_decoder_loss_list)
bgnn_avg_loss = np.mean(bgnn_decoder_loss_list)
bgnn_std_loss = np.std(bgnn_decoder_loss_list)
webgnn_avg_loss = np.mean(webgnn_decoder_loss_list)
webgnn_std_loss = np.std(webgnn_decoder_loss_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
gcn_avg_loss_str = "{:.4}".format(gcn_avg_loss)
gcn_std_loss_str = "{:.4}".format(gcn_std_loss)
gat_avg_loss_str = "{:.4}".format(gat_avg_loss)
gat_std_loss_str = "{:.4}".format(gat_std_loss)
gformer_avg_loss_str = "{:.4}".format(gformer_avg_loss)
gformer_std_loss_str = "{:.4}".format(gformer_std_loss)
mixhop_avg_loss_str = "{:.4}".format(mixhop_avg_loss)
mixhop_std_loss_str = "{:.4}".format(mixhop_std_loss)
gin_avg_loss_str = "{:.4}".format(gin_avg_loss)
gin_std_loss_str = "{:.4}".format(gin_std_loss)
bgnn_avg_loss_str = "{:.4}".format(bgnn_avg_loss)
bgnn_std_loss_str = "{:.4}".format(bgnn_std_loss)
webgnn_avg_loss_str = "{:.4}".format(webgnn_avg_loss)
webgnn_std_loss_str = "{:.4}".format(webgnn_std_loss)

drugcombfi_model_comparison_table_loss = pd.DataFrame({"avg":[gcn_avg_loss_str, gat_avg_loss_str, gformer_avg_loss_str, mixhop_avg_loss_str, gin_avg_loss_str, bgnn_avg_loss_str, webgnn_avg_loss_str],
                                            "std":[gcn_std_loss_str, gat_std_loss_str, gformer_std_loss_str, mixhop_std_loss_str, gin_std_loss_str, bgnn_std_loss_str, webgnn_std_loss_str]},
                                            index=["GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])

display(drugcombfi_model_comparison_table_loss)
# Out:
#            avg    std
# GCN      180.5  9.234
# GAT      205.5  10.46
# GFORMER  167.1  10.35
# MIXHOP   181.9  14.25
# GIN      343.7  288.6
# BGNN     159.0  6.004
# WEBGNN   137.1  4.972

# %% [markdown]
# # 4. DrugComb-DB

# %% [markdown]
# ## 4.1 DrugComb-DB Pearson Correlation

# %%
xgboost_test_list = [0.515926, 0.496845, 0.517539, 0.522624, 0.540706]
rf_test_list = [0.649099, 0.629549, 0.644015, 0.647977, 0.670877]
gcn_decoder_test_list = [0.4442494431032748, 0.48119880089480205, 0.37986382381153067, 0.4699403045877673, 0.46817838197260764]
gat_decoder_test_list = [0.45805605037257663, 0.4444301739269721, 0.4149404187871481, 0.4002755255500158, 0.4529279612278774]
gformer_decoder_test_list = [0.4782026731873965, 0.47048927203851526, 0.4956673707594276, 0.40800539445403383, 0.3893487433599303]
mixhop_decoder_test_list = [0.053064986570563626, 0.04021189331436391, 0.06916652642027507, 0.11331714263590105, 0.055232252149802784]
gin_decoder_test_list = [0.4345694056192812, 0.4213814614414578, 0.3270187009144137, 0.4523135880791608, 0.49424196143653115]
bgnn_decoder_test_list = [0.5500947945565586, 0.5311570467215128, 0.5582436928912344, 0.5334253455064432, 0.5965699828533841]
webgnn_decoder_test_list = [0.6154503815710425, 0.6036536956792591, 0.6141593097728945, 0.6207235304192388, 0.6214731943895582]

# %%
# calculate the average and std of the test results
xgboost_avg = np.mean(xgboost_test_list)
xgboost_std = np.std(xgboost_test_list)
rf_avg = np.mean(rf_test_list)
rf_std = np.std(rf_test_list)
gcn_avg = np.mean(gcn_decoder_test_list)
gcn_std = np.std(gcn_decoder_test_list)
gat_avg = np.mean(gat_decoder_test_list)
gat_std = np.std(gat_decoder_test_list)
gformer_avg = np.mean(gformer_decoder_test_list)
gformer_std = np.std(gformer_decoder_test_list)
mixhop_avg = np.mean(mixhop_decoder_test_list)
mixhop_std = np.std(mixhop_decoder_test_list)
gin_avg = np.mean(gin_decoder_test_list)
gin_std = np.std(gin_decoder_test_list)
bgnn_avg = np.mean(bgnn_decoder_test_list)
bgnn_std = np.std(bgnn_decoder_test_list)
webgnn_avg = np.mean(webgnn_decoder_test_list)
webgnn_std = np.std(webgnn_decoder_test_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
xgboost_avg_str = "{:.2%}".format(xgboost_avg)
xgboost_std_str = "{:.2%}".format(xgboost_std)
rf_avg_str = "{:.2%}".format(rf_avg)
rf_std_str = "{:.2%}".format(rf_std)
gcn_avg_str = "{:.2%}".format(gcn_avg)
gcn_std_str = "{:.2%}".format(gcn_std)
gat_avg_str = "{:.2%}".format(gat_avg)
gat_std_str = "{:.2%}".format(gat_std)
gformer_avg_str = "{:.2%}".format(gformer_avg)
gformer_std_str = "{:.2%}".format(gformer_std)
mixhop_avg_str = "{:.2%}".format(mixhop_avg)
mixhop_std_str = "{:.2%}".format(mixhop_std)
gin_avg_str = "{:.2%}".format(gin_avg)
gin_std_str = "{:.2%}".format(gin_std)
bgnn_avg_str = "{:.2%}".format(bgnn_avg)
bgnn_std_str = "{:.2%}".format(bgnn_std)
webgnn_avg_str = "{:.2%}".format(webgnn_avg)
webgnn_std_str = "{:.2%}".format(webgnn_std)

drugcombdb_model_comparison_table = pd.DataFrame({"avg":[xgboost_avg_str, rf_avg_str, gcn_avg_str, gat_avg_str, gformer_avg_str, mixhop_avg_str, gin_avg_str, bgnn_avg_str, webgnn_avg_str],
                                            "std":[xgboost_std_str, rf_std_str, gcn_std_str, gat_std_str, gformer_std_str, mixhop_std_str, gin_std_str, bgnn_std_str, webgnn_std_str]},
                                            index=["XGBOOST", "RANDOM-FOREST",  "GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])

display(drugcombdb_model_comparison_table)
# Out:
#                   avg    std
# XGBOOST        51.87%  1.40%
# RANDOM-FOREST  64.83%  1.33%
# GCN            44.87%  3.65%
# GAT            43.41%  2.26%
# GFORMER        44.83%  4.18%
# MIXHOP          6.62%  2.53%
# GIN            42.59%  5.52%
# BGNN           55.39%  2.36%
# WEBGNN         61.51%  0.64%

# %% [markdown]
# ## 4.2 DrugComb-DB MSE Loss

# %%
gcn_decoder_loss_list = [205.07731051195614, 217.25541042672614, 260.6371376322352, 218.84816746176057, 215.15267972844032]
gat_decoder_loss_list = [202.05119133332815, 226.69753055535094, 245.5635604790345, 238.54944531668878, 220.64003749000892]
gformer_decoder_loss_list = [199.10467178827898, 221.84681414800468, 224.21966666807032, 233.65451924178308, 241.04037113126992]
mixhop_decoder_loss_list = [7242.73480957766, 24582.9176148857, 4128.24326877227, 1541.5421177431779, 9479.328484365693]
gin_decoder_loss_list = [209.34563656390367, 232.03487936528919, 271.2186914549181, 222.88108170353507, 207.9519413423245]
bgnn_decoder_loss_list = [179.7907381845751, 202.39956216594598, 203.83703638641606, 201.0473376375656, 177.40495600754164]
webgnn_decoder_loss_list = [163.61726328810673, 181.33687884276551, 184.46956434472295, 172.63856701756006, 168.97727840441001]

# %%
# calculate the average and std of the loss results
gcn_avg_loss = np.mean(gcn_decoder_loss_list)
gcn_std_loss = np.std(gcn_decoder_loss_list)
gat_avg_loss = np.mean(gat_decoder_loss_list)
gat_std_loss = np.std(gat_decoder_loss_list)
gformer_avg_loss = np.mean(gformer_decoder_loss_list)
gformer_std_loss = np.std(gformer_decoder_loss_list)
mixhop_avg_loss = np.mean(mixhop_decoder_loss_list)
mixhop_std_loss = np.std(mixhop_decoder_loss_list)
gin_avg_loss = np.mean(gin_decoder_loss_list)
gin_std_loss = np.std(gin_decoder_loss_list)
bgnn_avg_loss = np.mean(bgnn_decoder_loss_list)
bgnn_std_loss = np.std(bgnn_decoder_loss_list)
webgnn_avg_loss = np.mean(webgnn_decoder_loss_list)
webgnn_std_loss = np.std(webgnn_decoder_loss_list)

# convery the avg and std to percentage and as string and make it as model comparison table (model as the rows and avg and std as the columns)
gcn_avg_loss_str = "{:.4}".format(gcn_avg_loss)
gcn_std_loss_str = "{:.4}".format(gcn_std_loss)
gat_avg_loss_str = "{:.4}".format(gat_avg_loss)
gat_std_loss_str = "{:.4}".format(gat_std_loss)
gformer_avg_loss_str = "{:.4}".format(gformer_avg_loss)
gformer_std_loss_str = "{:.4}".format(gformer_std_loss)
mixhop_avg_loss_str = "{:.4}".format(mixhop_avg_loss)
mixhop_std_loss_str = "{:.4}".format(mixhop_std_loss)
gin_avg_loss_str = "{:.4}".format(gin_avg_loss)
gin_std_loss_str = "{:.4}".format(gin_std_loss)
bgnn_avg_loss_str = "{:.4}".format(bgnn_avg_loss)
bgnn_std_loss_str = "{:.4}".format(bgnn_std_loss)
webgnn_avg_loss_str = "{:.4}".format(webgnn_avg_loss)
webgnn_std_loss_str = "{:.4}".format(webgnn_std_loss)

drugcombdb_model_comparison_table_loss = pd.DataFrame({"avg":[gcn_avg_loss_str, gat_avg_loss_str, gformer_avg_loss_str, mixhop_avg_loss_str, gin_avg_loss_str, bgnn_avg_loss_str, webgnn_avg_loss_str],
                                            "std":[gcn_std_loss_str, gat_std_loss_str, gformer_std_loss_str, mixhop_std_loss_str, gin_std_loss_str, bgnn_std_loss_str, webgnn_std_loss_str]},
                                            index=["GCN", "GAT", "GFORMER", "MIXHOP", "GIN", "BGNN", "WEBGNN"])

display(drugcombdb_model_comparison_table_loss)
# Out:
#                avg        std
# GCN          223.4      19.23
# GAT          226.7       15.1
# GFORMER      224.0       14.2
# MIXHOP   9.395e+03  8.059e+03
# GIN          228.7      23.06
# BGNN         192.9      11.73
# WEBGNN       174.2      7.722

# %% [markdown]
# # 5. Combine all the dataset results

# %%
# concat all datasets avg and std test results and loss results one two dataframes (combine avg and std as one column with plus minus sign in string; and model as rows and dataset as columns)
nci_model_comparison_table["NCI ALMANAC"] = nci_model_comparison_table["avg"] + " ± " + nci_model_comparison_table["std"]
nci_model_comparison_table.drop(columns=["avg", "std"], inplace=True)
oneil_model_comparison_table["ONEIL"] = oneil_model_comparison_table["avg"] + " ± " + oneil_model_comparison_table["std"]
oneil_model_comparison_table.drop(columns=["avg", "std"], inplace=True)
drugcombfi_model_comparison_table["DrugComb"] = drugcombfi_model_comparison_table["avg"] + " ± " + drugcombfi_model_comparison_table["std"]
drugcombfi_model_comparison_table.drop(columns=["avg", "std"], inplace=True)
drugcombdb_model_comparison_table["DrugCombDB"] = drugcombdb_model_comparison_table["avg"] + " ± " + drugcombdb_model_comparison_table["std"]
drugcombdb_model_comparison_table.drop(columns=["avg", "std"], inplace=True)

model_comparison_table = pd.concat([nci_model_comparison_table, oneil_model_comparison_table, drugcombfi_model_comparison_table, drugcombdb_model_comparison_table], axis=1)
display(model_comparison_table)
model_comparison_table.to_csv("./model_comparison_table.csv")
# Out:
#                    NCI ALMANAC            ONEIL         DrugComb  \
# XGBOOST         59.51% ± 3.40%   66.11% ± 2.29%   55.12% ± 1.03%
# RANDOM-FOREST   62.36% ± 3.77%   68.31% ± 1.41%   65.28% ± 0.32%
# GCN             44.88% ± 4.87%   50.07% ± 8.16%   46.40% ± 1.58%
# GAT             20.37% ± 7.08%  31.54% ± 15.34%   31.61% ± 6.18%
# GFORMER         36.39% ± 4.51%  28.66% ± 14.12%   52.49% ± 2.04%
# MIXHOP         48.13% ± 14.36%    6.93% ± 5.08%   46.77% ± 2.60%
# GIN             52.94% ± 5.28%   23.34% ± 9.37%  31.95% ± 13.93%
# BGNN            48.32% ± 5.79%   61.36% ± 3.09%   55.35% ± 0.91%
# WEBGNN          63.75% ± 1.58%   65.81% ± 2.83%   63.68% ± 0.92%
#
#                    DrugCombDB
# XGBOOST        51.87% ± 1.40%
# RANDOM-FOREST  64.83% ± 1.33%
# GCN            44.87% ± 3.65%
# GAT            43.41% ± 2.26%
# GFORMER        44.83% ± 4.18%
# MIXHOP          6.62% ± 2.53%
# GIN            42.59% ± 5.52%
# BGNN           55.39% ± 2.36%
# WEBGNN         61.51% ± 0.64%

# %%
# concat all datasets avg and std test results and loss results one two dataframes (combine avg and std as one column with plus minus sign in string; and model as rows and dataset as columns)
nci_model_comparison_table_loss["NCI ALMANAC"] = nci_model_comparison_table_loss["avg"] + " ± " + nci_model_comparison_table_loss["std"]
nci_model_comparison_table_loss.drop(columns=["avg", "std"], inplace=True)
oneil_model_comparison_table_loss["ONEIL"] = oneil_model_comparison_table_loss["avg"] + " ± " + oneil_model_comparison_table_loss["std"]
oneil_model_comparison_table_loss.drop(columns=["avg", "std"], inplace=True)
drugcombfi_model_comparison_table_loss["DrugComb"] = drugcombfi_model_comparison_table_loss["avg"] + " ± " + drugcombfi_model_comparison_table_loss["std"]
drugcombfi_model_comparison_table_loss.drop(columns=["avg", "std"], inplace=True)
drugcombdb_model_comparison_table_loss["DrugCombDB"] = drugcombdb_model_comparison_table_loss["avg"] + " ± " + drugcombdb_model_comparison_table_loss["std"]
drugcombdb_model_comparison_table_loss.drop(columns=["avg", "std"], inplace=True)

model_comparison_table_loss = pd.concat([nci_model_comparison_table_loss, oneil_model_comparison_table_loss, drugcombfi_model_comparison_table_loss, drugcombdb_model_comparison_table_loss], axis=1)
display(model_comparison_table_loss)
model_comparison_table_loss.to_csv("./model_comparison_table_loss.csv")
# Out:
#            NCI ALMANAC                  ONEIL       DrugComb  \
# GCN      57.74 ± 5.943          207.6 ± 30.81  180.5 ± 9.234
# GAT      70.29 ± 3.841          330.7 ± 203.5  205.5 ± 10.46
# GFORMER  62.27 ± 4.369  2.789e+04 ± 5.488e+04  167.1 ± 10.35
# MIXHOP     87.4 ± 69.6  1.849e+06 ± 1.358e+06  181.9 ± 14.25
# GIN      51.58 ± 6.456  3.347e+03 ± 5.687e+03  343.7 ± 288.6
# BGNN     55.38 ± 6.672          172.4 ± 14.95  159.0 ± 6.004
# WEBGNN    43.16 ± 4.69          157.7 ± 16.04  137.1 ± 4.972
#
#                     DrugCombDB
# GCN              223.4 ± 19.23
# GAT               226.7 ± 15.1
# GFORMER           224.0 ± 14.2
# MIXHOP   9.395e+03 ± 8.059e+03
# GIN              228.7 ± 23.06
# BGNN             192.9 ± 11.73
# WEBGNN           174.2 ± 7.722
